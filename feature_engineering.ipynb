# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import json

# %%
train = pd.read_pickle('./input/data-science-bowl-2019/train.pkl')
test = pd.read_pickle('./input/data-science-bowl-2019/test.pkl')
train_labels = pd.read_pickle('./input/data-science-bowl-2019/train_labels.pkl') 
specs = pd.read_pickle('./input/data-science-bowl-2019/specs.pkl')
sample_submission = pd.read_pickle('./input/data-science-bowl-2019/sample_submission.pkl')

print(f"train shape: {train.shape}")
print(f"test shape: {test.shape}")
print(f"train labels shape: {train_labels.shape}")
print(f"specs shape: {specs.shape}")
print(f"sample submission shape: {sample_submission.shape}")
# Out:
# train shape: (11341042, 11)
# test shape: (1156414, 11)
# train labels shape: (17690, 7)
# specs shape: (386, 3)
# sample submission shape: (1000, 2)

# %%
keep_id = train[train.type == "Assessment"][['installation_id']].drop_duplicates()
train = pd.merge(train, keep_id, on="installation_id", how="inner")
train[(train['title'] == 'Bird Measurer (Assessment)') & (train['event_code'] == 4110) | (train['title'] != 'Bird Measurer (Assessment)') & (train['event_code'] == 4100)]
# Out:
#          event_id      game_session                 timestamp  \
# 690      25fa8af4  901acc108f55a5a1  2019-08-06T05:22:32.357Z
# 770      14de4c5d  80d34a30c2998653  2019-08-06T05:24:50.323Z
# 797      14de4c5d  80d34a30c2998653  2019-08-06T05:25:11.292Z
# 837      14de4c5d  80d34a30c2998653  2019-08-06T05:25:37.207Z
# 871      14de4c5d  80d34a30c2998653  2019-08-06T05:26:01.055Z
# 1171     17113b36  77b8ee947eb84b4e  2019-08-06T05:35:54.898Z
# 1177     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:01.927Z
# 1182     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:06.512Z
# 1187     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:09.739Z
# 1192     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:13.951Z
# 1195     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:17.407Z
# 1200     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:21.390Z
# 1205     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:26.296Z
# 1212     17113b36  77b8ee947eb84b4e  2019-08-06T05:36:32.187Z
# ...

# %%
train.shape
# Out:
# (8294138, 11)

# %%
def get_time(df):
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df['date'] = df['timestamp'].dt.date
    df['month'] = df['timestamp'].dt.month
    df['hour'] = df['timestamp'].dt.hour
    df['dayofweek'] = df['timestamp'].df.dayofweek
    return df

# %%
train_labels.shape
# Out:
# (17690, 7)

# %%
train['game_session'].nunique()
# Out:
# 195445
